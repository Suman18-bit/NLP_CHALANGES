# %% [markdown]
# <a href="https://colab.research.google.com/github/Suman18-bit/NLP_CHALANGES/blob/main/NER.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import spacy

# %%
from spacy import displacy

# %%
ner_pipeline=spacy.load("en_core_web_sm")

# %%
print(ner_pipeline.meta['version'])
# Out:
# 3.8.0

# %%
ner_pipeline_labels=ner_pipeline.pipe_labels['ner']

# %%
print(ner_pipeline_labels)
# Out:
# ['CARDINAL', 'DATE', 'EVENT', 'FAC', 'GPE', 'LANGUAGE', 'LAW', 'LOC', 'MONEY', 'NORP', 'ORDINAL', 'ORG', 'PERCENT', 'PERSON', 'PRODUCT', 'QUANTITY', 'TIME', 'WORK_OF_ART']

# %%
spacy.explain('GPE')
# Out:
# 'Countries, cities, states'

# %%
spacy.explain('ORG')
# Out:
# 'Companies, agencies, institutions, etc.'

# %%
spacy.explain('WORK_OF_ART')
# Out:
# 'Titles of books, songs, etc.'

# %%
spacy.explain('NORP')
# Out:
# 'Nationalities or religious or political groups'

# %%
spacy.explain('LOC')
# Out:
# 'Non-GPE locations, mountain ranges, bodies of water'

# %%
artical="""In May 2026, the Global Sustainability and Technology Conference was hosted in Dubai, United Arab Emirates, bringing together more than 200 heads of state, CEOs,
 and researchers from across the world. The opening ceremony featured speeches by Ursula von der Leyen, President of the European Commission, Justin Trudeau, Prime Minister
  of Canada, and Sheryl Sandberg, former COO of Meta. The event was organized by the United Nations, the World Bank, and the International Energy Agency, with sponsorship
  from corporations such as Siemens, IBM, and Huawei. On May 5, 2026, the Government of India announced a ₹500 billion investment in renewable energy, while the United States
   pledged $70 billion for AI‑driven healthcare initiatives. Delegations from countries including Argentina, Nigeria, South Korea, and Australia signed agreements to collaborate
   on climate resilience projects. Researchers from MIT, Cambridge University, and the Indian Institute of Technology Bombay presented groundbreaking studies on the role of
   machine learning in predicting natural disasters. Journalists from The New York Times, The Guardian, and Al Jazeera reported extensively, highlighting both optimism and
   skepticism. Environmental groups such as Greenpeace, WWF, and Friends of the Earth praised the commitments, while oil corporations like BP, Chevron, and Saudi Aramco raised
   concerns about economic feasibility. On May 10, 2026, the International Monetary Fund released a report forecasting global GDP growth of 4.2% in 2027, with Asia and Africa
   expected to lead. Meanwhile, NGOs like Amnesty International, Oxfam, and CARE International warned about inequality in access to new technologies. The conference concluded
    on May 12, 2026, with a declaration signed by 135 nations committing to reduce global carbon emissions by 60% before 2050. António Guterres, the UN Secretary‑General,
     called it “a turning point in human history.” Analysts from Goldman Sachs, McKinsey, and Deloitte predicted major shifts in global markets, while PwC emphasized the
      need for stronger cybersecurity frameworks. The summit was widely regarded as one of the most ambitious gatherings in modern history, with ripple effects expected
      across Europe, Latin America, the Middle East, and Southeast Asia.
"""

# %%
len(artical.split('.'))
# Out:
# 16

# %%
ner = ner_pipeline(artical)

# %%
for word in ner.ents:
    print("OBJECT:-",word.text,",NAME ENTITY:-", word.label_)
# Out:
# OBJECT:- May 2026 ,NAME ENTITY:- DATE
# OBJECT:- the Global Sustainability and Technology Conference ,NAME ENTITY:- ORG
# OBJECT:- Dubai ,NAME ENTITY:- GPE
# OBJECT:- United Arab Emirates ,NAME ENTITY:- GPE
# OBJECT:- more than 200 ,NAME ENTITY:- CARDINAL
# OBJECT:- Ursula von der ,NAME ENTITY:- PERSON
# OBJECT:- Leyen ,NAME ENTITY:- GPE
# OBJECT:- the European Commission ,NAME ENTITY:- ORG
# OBJECT:- Justin Trudeau ,NAME ENTITY:- PERSON
# OBJECT:- Canada ,NAME ENTITY:- GPE
# OBJECT:- Sheryl Sandberg ,NAME ENTITY:- PERSON
# OBJECT:- COO ,NAME ENTITY:- ORG
# OBJECT:- Meta ,NAME ENTITY:- ORG
# OBJECT:- the United Nations ,NAME ENTITY:- ORG
# OBJECT:- the World Bank ,NAME ENTITY:- ORG
# OBJECT:- the International Energy Agency ,NAME ENTITY:- ORG
# OBJECT:- Siemens ,NAME ENTITY:- ORG
# OBJECT:- IBM ,NAME ENTITY:- ORG
# OBJECT:- Huawei ,NAME ENTITY:- ORG
# OBJECT:- May 5, 2026 ,NAME ENTITY:- DATE
# OBJECT:- the Government of India ,NAME ENTITY:- ORG
# ...

# %%
for word in ner.ents:
    print("OBJECT:-",word.text,",NAME ENTITY:-", word.label_,"WORD START CHARACTR:-",word.start_char,"WORD END CHARACTR:-",word.end_char)
# Out:
# OBJECT:- May 2026 ,NAME ENTITY:- DATE WORD START CHARACTR:- 3 WORD END CHARACTR:- 11
# OBJECT:- the Global Sustainability and Technology Conference ,NAME ENTITY:- ORG WORD START CHARACTR:- 13 WORD END CHARACTR:- 64
# OBJECT:- Dubai ,NAME ENTITY:- GPE WORD START CHARACTR:- 79 WORD END CHARACTR:- 84
# OBJECT:- United Arab Emirates ,NAME ENTITY:- GPE WORD START CHARACTR:- 86 WORD END CHARACTR:- 106
# OBJECT:- more than 200 ,NAME ENTITY:- CARDINAL WORD START CHARACTR:- 126 WORD END CHARACTR:- 139
# OBJECT:- Ursula von der ,NAME ENTITY:- PERSON WORD START CHARACTR:- 244 WORD END CHARACTR:- 258
# OBJECT:- Leyen ,NAME ENTITY:- GPE WORD START CHARACTR:- 259 WORD END CHARACTR:- 264
# OBJECT:- the European Commission ,NAME ENTITY:- ORG WORD START CHARACTR:- 279 WORD END CHARACTR:- 302
# OBJECT:- Justin Trudeau ,NAME ENTITY:- PERSON WORD START CHARACTR:- 304 WORD END CHARACTR:- 318
# OBJECT:- Canada ,NAME ENTITY:- GPE WORD START CHARACTR:- 340 WORD END CHARACTR:- 346
# ...

# %%
len([ent for ent in ner.ents if ent.label_=="ORG"]) # number of occurance in the document of ORD
# Out:
# 30

# %%
displacy.render(ner,style="ent",jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">In
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     May 2026
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# ,
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the Global Sustainability and Technology Conference
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  was hosted in
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Dubai
# ...
