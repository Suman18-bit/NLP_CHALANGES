# %% [markdown]
# <a href="https://colab.research.google.com/github/Suman18-bit/NLP_CHALANGES/blob/main/Text_Summarization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install sumy
# Out:
# Collecting sumy
#   Downloading sumy-0.12.0-py3-none-any.whl.metadata (8.3 kB)
# Collecting breadability>=0.1.20 (from sumy)
#   Downloading breadability-0.1.20.tar.gz (32 kB)
#   Preparing metadata (setup.py) ... done
# Collecting docopt-ng>=0.6.1 (from sumy)
#   Downloading docopt_ng-0.9.0-py3-none-any.whl.metadata (13 kB)
# Collecting lxml-html-clean (from sumy)
#   Downloading lxml_html_clean-0.4.5-py3-none-any.whl.metadata (2.4 kB)
# Requirement already satisfied: nltk>=3.0.2 in /usr/local/lib/python3.12/dist-packages (from sumy) (3.9.1)
# Collecting pycountry>=18.2.23 (from sumy)
#   Downloading pycountry-26.2.16-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: requests>=2.7.0 in /usr/local/lib/python3.12/dist-packages (from sumy) (2.32.4)
# Requirement already satisfied: setuptools>=65.0.0 in /usr/local/lib/python3.12/dist-packages (from sumy) (75.2.0)
# Collecting docopt<0.7,>=0.6.1 (from breadability>=0.1.20->sumy)
#   Downloading docopt-0.6.2.tar.gz (25 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: chardet in /usr/local/lib/python3.12/dist-packages (from breadability>=0.1.20->sumy) (5.2.0)
# Requirement already satisfied: lxml>=2.0 in /usr/local/lib/python3.12/dist-packages (from breadability>=0.1.20->sumy) (6.1.1)
# Requirement already satisfied: click in /usr/local/lib/python3.12/dist-packages (from nltk>=3.0.2->sumy) (8.4.1)
# Requirement already satisfied: joblib in /usr/local/lib/python3.12/dist-packages (from nltk>=3.0.2->sumy) (1.5.3)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.12/dist-packages (from nltk>=3.0.2->sumy) (2025.11.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from nltk>=3.0.2->sumy) (4.67.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.7.0->sumy) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.7.0->sumy) (3.18)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.7.0->sumy) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.7.0->sumy) (2026.5.20)
# Downloading sumy-0.12.0-py3-none-any.whl (73 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.5/73.5 kB 3.4 MB/s eta 0:00:00
# Downloading docopt_ng-0.9.0-py3-none-any.whl (16 kB)
# Downloading pycountry-26.2.16-py3-none-any.whl (8.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.0/8.0 MB 26.4 MB/s eta 0:00:00
# Downloading lxml_html_clean-0.4.5-py3-none-any.whl (14 kB)
# Building wheels for collected packages: breadability, docopt
#   Building wheel for breadability (setup.py) ... done
#   Created wheel for breadability: filename=breadability-0.1.20-py2.py3-none-any.whl size=21695 sha256=b0fc709c3db40c326ab649b5b98be0e782b5ce9ddec282552aa42d321e22da0a
#   Stored in directory: /root/.cache/pip/wheels/32/99/64/59305409cacd03aa03e7bddf31a9db34b1fa7033bd41972662
#   Building wheel for docopt (setup.py) ... done
#   Created wheel for docopt: filename=docopt-0.6.2-py2.py3-none-any.whl size=13706 sha256=ed7f9d6df9d605bac9b3692d2178769f10f2e075b1f1a8e9224b620b9fec117e
#   Stored in directory: /root/.cache/pip/wheels/1a/bf/a1/4cee4f7678c68c5875ca89eaccf460593539805c3906722228
# Successfully built breadability docopt
# Installing collected packages: docopt, pycountry, lxml-html-clean, docopt-ng, breadability, sumy
# Successfully installed breadability-0.1.20 docopt-0.6.2 docopt-ng-0.9.0 lxml-html-clean-0.4.5 pycountry-26.2.16 sumy-0.12.0

# %%
import sumy
from sumy.parsers.plaintext import PlaintextParser
from sumy.nlp.tokenizers import Tokenizer
from sumy.summarizers.lex_rank import LexRankSummarizer
from sumy.parsers.html import HtmlParser
from sumy.summarizers.lsa import LsaSummarizer

# %%
sample_text = """There is a massive shift underway in the global economy. Fueled by rapid advancements in artificial intelligence, we are witnessing a fundamental redesign of the modern workplace.

This has led to a dramatic transformation in how we create, collaborate, and innovate. The pace of technological evolution has never been faster, with generative AI tools accomplishing in seconds what previously took days. At LinkedIn, we see this as "The AI Era".

Running in parallel with this technological leap is the urgent need for human adaptability. Industry leaders emphasize that AI will not replace humans, but humans who use AI will replace those who don't.

Our hope is that we can collectively embrace this disruption as a catalyst for growth. We can all elevate our careers by developing AI literacy and integrating these tools into our daily workflows.

Emerging roles include Prompt Engineers, AI Ethics Officers, Automation Consultants, and Machine Learning Analysts: positions that are rapidly becoming the most sought-after across every major industry.

So what does this mean for you? How can you future-proof your career for the intelligent economy that lies ahead?

In my new LinkedIn Learning course, Thriving in the AI-Powered Workplace, I'll help you demystify artificial intelligence and identify the practical opportunities it presents. You'll learn how to leverage AI alongside your unique human skills.

Remember - innovation starts with you! Whether you're an entry-level professional or a seasoned executive, here are three steps you can take to accelerate your career in the AI era.

Build your AI literacy and technical intuition
Understanding how to interact with AI is critical for emerging career opportunities. Globally, professionals who actively adopt AI tools are reporting higher productivity and job satisfaction. So start familiarizing yourself with the leading generative platforms.

Meanwhile, within your current role, look for repetitive tasks that could be automated or enhanced by AI. Why not propose a pilot project to your employer demonstrating how AI could streamline your team's workflow?

Cultivate a network of tech-forward professionals
Your professional community is your greatest asset in navigating technological change. That's because shared knowledge accelerates individual learning. But you must actively participate!

Our data shows that early adopters of AI tend to collaborate more broadly across different departments. Your network is the key to discovering innovative use cases, sparking creative ideas, and staying ahead of the curve.

So start seeking out AI-focused content that aligns with your industry, and consider adding your own perspective by commenting on it or sharing relevant articles.

Why not join a LinkedIn Group dedicated to practical AI applications in your field? And if you're feeling adventurous, you can even start a weekly knowledge-sharing session with your peers.

That way, you'll spark new discussions which could unlock unforeseen opportunities for both your career and your entire network."""

# %%
import nltk
nltk.download("punkt")
nltk.download("punkt_tab")
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# True

# %%
len(sample_text.split("."))
# Out:
# 25

# %%
string_parser = PlaintextParser.from_string(sample_text, Tokenizer("english"))

# %%
Lex = LexRankSummarizer()
Lex_summary = Lex(string_parser.document, sentences_count=5)

# %%
Lex_summary
# Out:
# (<Sentence: Our hope is that we can collectively embrace this disruption as a catalyst for growth.>,
#  <Sentence: How can you future-proof your career for the intelligent economy that lies ahead?>,
#  <Sentence: In my new LinkedIn Learning course, Thriving in the AI-Powered Workplace, I'll help you demystify artificial intelligence and identify the practical opportunities it presents.>,
#  <Sentence: Globally, professionals who actively adopt AI tools are reporting higher productivity and job satisfaction.>,
#  <Sentence: So start familiarizing yourself with the leading generative platforms.>)

# %%
Lsa = LsaSummarizer()
Lsa_summary = Lex(string_parser.document, sentences_count=5)

# %%
Lsa_summary
# Out:
# (<Sentence: Our hope is that we can collectively embrace this disruption as a catalyst for growth.>,
#  <Sentence: How can you future-proof your career for the intelligent economy that lies ahead?>,
#  <Sentence: In my new LinkedIn Learning course, Thriving in the AI-Powered Workplace, I'll help you demystify artificial intelligence and identify the practical opportunities it presents.>,
#  <Sentence: Globally, professionals who actively adopt AI tools are reporting higher productivity and job satisfaction.>,
#  <Sentence: So start familiarizing yourself with the leading generative platforms.>)

# %%
url = "https://en.wikipedia.org/wiki/Cricket"
html_parser = HtmlParser.from_url(url, Tokenizer('english'))
html_lex_summary = Lex(document=html_parser.document,sentences_count=20)

# %%
html_lex_summary
# Out:
# (<Sentence: Two players from the batting team, the striker and nonstriker, stand in front of either wicket holding bats, while one player from the fielding team, the bowler, bowls the ball toward the striker's wicket from the opposite end of the pitch.>,
#  <Sentence: Dismissal can occur in various ways, including being bowled(when the ball hits the striker's wicket and dislodges the bails), and by the fielding side either catching the ball after it is hit by the bat but before it hits the ground, or hitting a wicket with the ball before a batter can cross the crease line in front of the wicket.>,
#  <Sentence: The game's rules, the Laws of Cricket, are maintained by Marylebone Cricket Club(MCC) in London.>,
#  <Sentence: The main objective of each team is to score more runs than their opponents, but in some forms of cricket, it is also necessary to dismiss all but one of the opposition batters (making their team 'all out') in their final innings in order to win the match, which would otherwise be drawn(not ending with a winner or tie.>,
#  <Sentence: The bowler (4) is bowling the ball(5) from their end of the pitch to the batter (8) at the other end who is called the "striker".>,
#  <Sentence: Sachin Tendulkar is the only player to have scored one hundred international centuries.The batter on strike (i.e., the "striker") must prevent the ball from hitting the wicket and try to score runs by hitting the ball with their bat so that the batter and their partner have time to switch places, with each of them running from one end of the pitch to the other before the fielding side can return the ball and attempt a run out(throwing the ball at one of the wickets before the run is scored.)>,
#  <Sentence: This is achieved in four ways: no-ball, a penalty of one extra conceded by the bowler if they break the rules (often by failing to bowl the ball before their front foot passes the popping crease at their end);[103] wide, a penalty of one extra conceded by the bowler if they bowl so that the ball is out of the batter's reach;[104] bye, an extra awarded if the batter misses the ball and it goes past the wicket-keeper and gives the batters time to run in the conventional way;[105] and leg bye, as for a bye except that the ball has hit the batter's body, though not their bat.>,
#  <Sentence: bowled – when the striker fails to prevent a delivery from hitting their wicket[ 106] caught – when a ball struck by the bat is caught by a fielder before it hits the ground[ 107] leg before wicket – when the striker's body 'unfairly' prevents a delivery from hitting the wicket[ 108] run out – generally when the ball is thrown at a wicket by a fielder while the batters are running between the wickets[ 109] stumped – a special type of run out involving the wicket-keeper and striker[ 110]>,
#  <Sentence: Match results are sometimes determined by a final dismissal, either because the batting team's last wicket falls, or in a limited-overs match, the chance to score is denied on the final delivery.There are a number of ways that a cricket match can end and its result be described, depending on whether the team batting first or last wins as well as the format of the game.>,
#  <Sentence: The innings terminates if the batting team is "all out", a term defined by the Laws: "At the fall of a wicket or the retirement of a batter, further balls remain to be bowled but no further batter is available to come in".>,
#  <Sentence: the batting team's captain may declare the innings closed, even though some of the captain's players have not had a turn to bat: this is a tactical decision by the captain, usually because the captain believes that their team have scored sufficient runs and need time to dismiss the opposition in their innings the set number of overs(i.e., in a limited overs match) have been bowled the match has ended prematurely due to bad weather or running out of time in the final innings of the match, the batting side has reached its target (i.e., scored more runs than the opposition) and won the game.>,
#  <Sentence: An umpire signals a decision to the scorers.The Adelaide Oval cricket scoreboard during an Ashes Test in AustraliaThe game on the field is regulated by the two umpires, one of whom stands behind the wicket at the bowler's end and the other in a position called "square leg", which is about 15–20 m (49–66 ft) away from the batter on strike and in line with the popping crease on which that umpire is taking guard.>,
#  <Sentence: [131] International development began at the start of the 20th century, and the first Test match was played between Australia and England in December 1934.>,
#  <Sentence: England and Wales Cricket Board 15 July 1909 IndiaBoard of Control for Cricket in India 31 May 1926 IrelandCricket Ireland 22 June 2017 New ZealandNew Zealand Cricket 31 May 1926 PakistanPakistan Cricket Board 28 July 1952 South AfricaCricket South Africa 15 July 1909 Sri LankaSri Lanka Cricket 21 July 1981 West IndiesCricket West Indies 31 May 1926 ZimbabweZimbabwe Cricket 6 July 1992
#  A Test match between South Africa and England in January 2005.>,
#  <Sentence: Teams in Test cricket, first-class cricket and club cricket wear traditional white uniforms and use red cricket balls.The highest standard is Test cricket(always written with a capital "T") which is in effect the international version of first-class cricket and is restricted to teams representing the twelve countries that are full members of the ICC (see above).>,
#  <Sentence: Although the term "Test match" was not coined until much later, Test cricket is deemed to have begun with two matches between Australia and England in the 1876–77 Australian season; since 1882, most Test series between England and Australia have been played for a trophy known as The Ashes.>,
#  <Sentence: Retrieved 11 December 2019.^"T20 Cricket".>,
#  <Sentence: Retrieved 2 July 2017.^"Laws".>,
#  <Sentence: Retrieved 2 July 2017.^"LAW 25 BATTER'S INNINGS; RUNNERS | MCC".>,
#  <Sentence: Retrieved 8 July 2017.^ Major (2007), pp.>)

# %%
html_lsa_summary = Lsa(document=html_parser.document,sentences_count=20)
