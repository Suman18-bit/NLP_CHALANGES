# %% [markdown]
# <a href="https://colab.research.google.com/github/Suman18-bit/NLP_CHALANGES/blob/main/TEXT_Preprocessing_ipynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import string
from sklearn.preprocessing import LabelEncoder
import warnings
import nltk
nltk.download('stopwords') # Download NLTK stopwords
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from sklearn.metrics.pairwise import cosine_similarity
stop=set(stopwords.words('english'))
warnings.filterwarnings("ignore")
from sklearn.feature_extraction.text import CountVectorizer
import string

stop = set(stopwords.words('english'))

def remove_num(txt):
    new = ''
    for i in str(txt): # Added str() to handle potential non-string data
        if not i.isdigit():
            new = new + i
    return new

def remove_pun(txt):
    # Fixed: The first two arguments should be empty strings, not ' '
    return str(txt).translate(str.maketrans('', '', string.punctuation))

def remove_stopwords(txt):
    word = str(txt).split()
    text = []
    for i in word:
        if i not in stop:
            text.append(i)
    # FIX: You were returning 'txt' (original). You must return " ".join(text)
    return " ".join(text)

def remove_emoji(txt):
    e = ""
    for i in str(txt):
        if i.isascii():
            e = e + i
    return e

def to_lower(txt):
    return str(txt).lower()

import pandas as pd
# !pip install langdetect
# !pip install deep_translator
from langdetect import detect
from deep_translator import GoogleTranslator

def translate_if_hindi(text):
    """
    Detects if the text is Hindi. If yes, translates to English.
    Otherwise, returns the original text.
    """
    # 1. Handle empty cells or missing data (NaN)
    if pd.isna(text) or not str(text).strip():
        return text

    # Convert to string just in case
    text = str(text)

    try:
        # 2. Detect the language
        # 'hi' is the standard language code for Hindi
        lang = detect(text)

        # 3. Translate if it is Hindi
        if lang == 'hi':
            # Translate from Hindi to English
            translated = GoogleTranslator(source='hi', target='en').translate(text)
            return translated
        else:
            # If it's English, Spanish, etc., leave it alone
            return text

    except Exception as e:
        # This catches errors (e.g., if the text is just numbers or emojis)
        # It will just return the original text without crashing
        return text

def master_clean(txt):
    # If the input is Null/NaN, return an empty string to avoid crashes
    if not isinstance(txt, str) and not isinstance(txt, (int, float)):
        return ""

    txt = to_lower(txt)
    txt = remove_emoji(txt)
    txt = remove_pun(txt)
    txt = remove_num(txt)
    txt = remove_stopwords(txt)
    txt = translate_if_hindi(txt)
    return txt
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 981.5/981.5 kB 14.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for langdetect: filename=langdetect-1.0.9-py3-none-any.whl size=993223 sha256=e925d0c50dadc889de73067e3558148fcc65316237409504dccca022902813dd
#   Stored in directory: /root/.cache/pip/wheels/c1/67/88/e844b5b022812e15a52e4eaa38a1e709e99f06f6639d7e3ba7
# Successfully built langdetect
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.3/42.3 kB 3.2 MB/s eta 0:00:00
# ...

# %%
Text = """
In 2024, Microsoft Corporation, headquartered in Redmond, Washington, announced a strategic partnership with OpenAI, aiming to accelerate advancements in
 artificial intelligence and cloud-based solutions. During the same year, Satya Nadella, the CEO of Microsoft, emphasized the importance of ethical AI at
 the World Economic Forum in Davos, Switzerland. Meanwhile, Google DeepMind, based in London, unveiled breakthroughs in protein folding research, which
 were later published in the journal Nature. Across the globe, India’s Ministry of Electronics and Information Technology (MeitY) launched initiatives to
support startups in Bengaluru and Hyderabad, focusing on machine learning, data engineering, and cybersecurity. In the entertainment industry, streaming
 platforms like Netflix, Disney+ Hotstar, and Spotify reported record user growth, particularly in regions such as South Asia and Latin America. Sports
 fans celebrated as Lionel Messi led Inter Miami CF to victory in the Major League Soccer (MLS) season, while cricket enthusiasts followed the TATA Indian
  Premier League (IPL), with matches between Mumbai Indians (MI) and Royal Challengers Bangalore (RCB) drawing millions of viewers. At the same time,
  universities like MIT, Stanford University, and the Indian Institute of Technology (IIT Bombay) expanded their research programs in quantum computing
   and natural language processing (NLP), collaborating with organizations such as the National Science Foundation (NSF) and UNESCO."""

# %%
Text_cleaned = master_clean(Text)

# %%
Text_cleaned
# Out:
# 'microsoft corporation headquartered redmond washington announced strategic partnership openai aiming accelerate advancements artificial intelligence cloudbased solutions year satya nadella ceo microsoft emphasized importance ethical ai world economic forum davos switzerland meanwhile google deepmind based london unveiled breakthroughs protein folding research later published journal nature across globe indias ministry electronics information technology meity launched initiatives support startups bengaluru hyderabad focusing machine learning data engineering cybersecurity entertainment industry streaming platforms like netflix disney hotstar spotify reported record user growth particularly regions south asia latin america sports fans celebrated lionel messi led inter miami cf victory major league soccer mls season cricket enthusiasts followed tata indian premier league ipl matches mumbai indians mi royal challengers bangalore rcb drawing millions viewers time universities like mit st
# ...
